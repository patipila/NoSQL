# %% [markdown]
# ---
# # PROJEKT: Analiza NYC Yellow Taxi Trip Data 2016
# ## Systemy Big Data i NoSQL
# ---
#
#
# ## 1. Wstęp i Opis Danych
#
# ### 1.1 Cel projektu
# Projekt ma na celu analizę danych dotyczących przejazdów taksówek w Nowym Jorku
# w roku 2016. Wykorzystujemy technologie Big Data (Apache Spark) oraz bazę NoSQL
# (MongoDB) do przetwarzania i analizy ~113 milionów rekordów.
#
# ### Zadania ML:
# 1. **Klasyfikacja** - przewidywanie wysokiego napiwku (>20% wartości przejazdu)
# 2. **Regresja** - przewidywanie całkowitej kwoty przejazdu

# %%
# %% Importy bibliotek
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.sql.window import Window

# ML imports
from pyspark.ml.feature import VectorAssembler, StandardScaler, StringIndexer
from pyspark.ml.classification import RandomForestClassifier
from pyspark.ml.regression import LinearRegression
from pyspark.ml.evaluation import (
    BinaryClassificationEvaluator, 
    MulticlassClassificationEvaluator,
    RegressionEvaluator
)
from pyspark.ml import Pipeline
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator

# MongoDB
from pymongo import MongoClient

# Wizualizacje i inne
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# Styl wykresów
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette("husl")
